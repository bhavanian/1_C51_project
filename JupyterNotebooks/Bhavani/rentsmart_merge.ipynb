# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import sklearn
from sklearn import manifold
from sklearn.manifold import TSNE
import matplotlib.cm as cm
from sklearn import cluster
from sklearn.cluster import KMeans
from sklearn import metrics
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn import linear_model
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
import math
import scipy
from scipy.spatial import distance_matrix
import itertools
import time

# %%
# Data Source: https://data.boston.gov/dataset/rentsmart
# Desc: Rentals only; Boston; 2016-present (previous years available 'through 1700s')

# "RentSmart Boston compiles data from BOS:311 and the City's Inspectional Services Division
# to give prospective tenants a more complete picture of the homes and apartments they are 
# considering renting, assisting them in understanding any previous issues with the property, 
# including: housing violations, building violations, enforcement violations, housing complaints,
# sanitation requests, and/or civic maintenance requests."

# %%
'''
TODO
- # occupants, race, and income

'''
# Out:
# '\nTODO\n- correlations in space, time, building characteristics with complaint number and frequency\n\n'

# %%
data_path = 'RentSmart/20220314_download/tmpdzll6bw0.csv'

# %%
df = pd.read_csv(data_path, parse_dates=['date'])

# %%
df.shape
# Out:
# (309756, 13)

# %%
addr_splt = [addr.split() for addr in df.address]

# %%
addr_splt[:5]
# Out:
# [['137', 'W', 'Ninth', 'St,', '02127'],
#  ['141', 'W', 'Ninth', 'St,', '02127'],
#  ['24-26', 'Faneuil', 'St,', '02135'],
#  ['39', 'Millmont', 'St,', '02119'],
#  ['19', 'Park', 'St,', '02122']]

# %%
for i in range(len(addr_splt)):
    if len(addr_splt[i]) != 4:
        addr_splt[i] = ['','','','']
    else:
        addr_splt[i][2] = addr_splt[i][2][:-1]
        addr_splt[i][1] = addr_splt[i][1].upper()
        addr_splt[i][2] = addr_splt[i][2].upper()

# %%
addr_splt[:5]
# Out:
# [['', '', '', ''],
#  ['', '', '', ''],
#  ['24-26', 'FANEUIL', 'ST', '02135'],
#  ['39', 'MILLMONT', 'ST', '02119'],
#  ['19', 'PARK', 'ST', '02122']]

# %%
df['st_num'] = None
df['st_name'] = None
df['st_name_suf'] = None
df['zipcode_str'] = None

# %%
df[['st_num','st_name','st_name_suf','zipcode_str']] = addr_splt

# %%
df
# Out:
#                           date              violation_type  \
# 0      2022-03-13 00:00:00.000      Enforcement Violations
# 1      2022-03-13 00:00:00.000      Enforcement Violations
# 2      2022-03-12 00:00:00.000      Enforcement Violations
# 3      2022-03-12 00:00:00.000      Enforcement Violations
# 4      2022-03-12 00:00:00.000      Enforcement Violations
# ...                        ...                         ...
# 309751 2017-04-09 14:22:00.000  Civic Maintenance Requests
# 309752 2017-04-09 14:03:00.000          Housing Complaints
# 309753 2017-04-09 13:31:48.610         Sanitation Requests
# 309754 2017-04-09 12:48:00.000         Sanitation Requests
# 309755 2017-04-09 10:58:00.000          Housing Complaints
#
#                            description                       address  \
# 0          Improper storage trash: res         137 W Ninth St, 02127
# 1          Improper storage trash: res         141 W Ninth St, 02127
# 2          Improper storage trash: res       24-26 Faneuil St, 02135
# 3          Improper storage trash: res         39 Millmont St, 02119
# 4          Improper storage trash: res             19 Park St, 02122
# ...                                ...                           ...
# 309751           Contractor Complaints      24 Nottinghill Rd, 02135
# 309752               Work w/out Permit      96-98 Brookley Rd, 02130
# 309753               Abandoned Bicycle        124 Chandler St, 02116
# 309754              Abandoned Vehicles      50 Florence St #3, 02131
# 309755  Heat - Excessive, Insufficient  370 Chestnut Hill Ave, 02135
#
#          neighborhood  zip_code      parcel                        owner  \
# 0        South Boston      2127   700334000        ONE-37 W NINTH STREET
# 1        South Boston      2127   700336000              LASOFF STEVEN S
# 2            Brighton      2135  2202558000                     LIU ZIYU
# 3             Roxbury      2119   903678000        THREENINEMILLMONT LLC
# 4          Dorchester      2122  1600041000              CORRIGAN JUSTIN
# ...               ...       ...         ...                          ...
# 309751       Brighton      2135  2102699000              METCHIK IRETA Z
# 309752  Jamaica Plain      2130  1102723000               PAYNE THOMAS M
# 309753         Boston      2116   400042000  ONE TWENTY FOUR CHANDLER ST
# 309754     Roslindale      2131  1904207000        ROSYLN MANOR CONDO TR
# 309755       Brighton      2135  2102352000     RESERVOIR PLACE CONDO TR
#
#         year built  year remodeled         property_type   latitude  \
# 0           1920.0          1992.0     Condominium Main*  42.334460
# 1           1885.0          1990.0  Residential 3-family  42.334370
# 2           1930.0          2015.0  Residential 2-family  42.355008
# 3           1900.0          2015.0  Residential 3-family  42.327532
# 4           1890.0          1996.0  Residential 2-family  42.301993
# ...            ...             ...                   ...        ...
# 309751      1925.0             NaN  Residential 1-family  42.343680
# 309752      1910.0             NaN  Residential 3-family  42.302863
# 309753      1999.0          2015.0     Condominium Main*  42.345980
# 309754      1999.0          1999.0     Condominium Main*  42.285120
# 309755      1999.0          1999.0     Condominium Main*  42.336651
#
#         longitude st_num      st_name st_name_suf zipcode_str
# 0      -71.054240
# 1      -71.054130
# 2      -71.151007  24-26      FANEUIL          ST       02135
# 3      -71.090943     39     MILLMONT          ST       02119
# 4      -71.053850     19         PARK          ST       02122
# ...           ...    ...          ...         ...         ...
# 309751 -71.149700     24  NOTTINGHILL          RD       02135
# 309752 -71.105433  96-98     BROOKLEY          RD       02130
# 309753 -71.074040    124     CHANDLER          ST       02116
# 309754 -71.126470
# 309755 -71.151138
#
# [309756 rows x 17 columns]

# %%
df.zip_code = df.zip_code.astype(float)

# %%
data_path2 = 'buildings_inventory/building_inventory_021020.csv'

# %%
building_df = pd.read_csv(data_path2,low_memory=False)

# %%
building_df.loc[building_df.st_name == 'MILLMONT',['st_num','st_name','st_name_suf','zipcode']]
# Out:
#        st_num   st_name st_name_suf  zipcode
# 7438        5  MILLMONT          ST   2119.0
# 8862       29  MILLMONT          ST   2119.0
# 56933      39  MILLMONT          ST   2119.0
# 72683      15  MILLMONT          ST   2119.0
# 72704  23 -25  MILLMONT          ST   2119.0
# 74342      46  MILLMONT          ST   2119.0
# 86341      14  MILLMONT          ST   2119.0
# 93925          MILLMONT          ST   2119.0
# 97951      16  MILLMONT          ST   2119.0

# %%
building_df[['st_num','st_name','st_name_suf','unit_num','zipcode']]
# Out:
#       st_num   st_name st_name_suf  unit_num  zipcode
# 0        NaN       NaN         NaN       NaN      NaN
# 1          5   EVERETT          ST       NaN   2122.0
# 2         43     ESSEX          ST       NaN   2129.0
# 3        525   WESTERN          AV       NaN   2135.0
# 4        NaN       NaN         NaN       NaN      NaN
# ...      ...       ...         ...       ...      ...
# 98925    NaN       NaN         NaN       NaN      NaN
# 98926     19    AVALON          RD       NaN   2132.0
# 98927     46  GERRISH           ST       NaN   2135.0
# 98928    NaN       NaN         NaN       NaN      NaN
# 98929     66   PERKINS          ST       NaN   2130.0
#
# [98930 rows x 5 columns]

# %%
building_df['unit_num'].unique()
# Out:
# array([nan])

# %%
df = df.merge(building_df,left_on=['st_num','st_name','st_name_suf','zip_code'],right_on=['st_num','st_name','st_name_suf','zipcode'],how='inner')

# %%
df.to_csv('rentsmart_withoccdata.csv')

# %%
df.shape
# Out:
# (127232, 121)

# %%
# perhaps should have done an outer merge
