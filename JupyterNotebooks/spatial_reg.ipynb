# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import sklearn
from sklearn import manifold
from sklearn.manifold import TSNE
import matplotlib.cm as cm
from sklearn import cluster
from sklearn.cluster import KMeans
from sklearn import metrics
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn import linear_model
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import math
import scipy
from scipy.spatial import distance_matrix
import itertools
import time

from pysal.explore import esda
#pip install pysal https://pysal.org/docs/install/
#pip install pandana additionally required
import geopandas
from pysal.lib import weights

# %%
# https://geographicdata.science/book/notebooks/06_spatial_autocorrelation.html?highlight=esda

# %%
df = pd.read_csv('address_clusters_withcomp.csv')

# %%
housing_complaints_counts_df = df[['address','violation_type_Housing Complaints','kmeans_labels']]

# %%
housing_complaints_counts_df = housing_complaints_counts_df.rename(columns={'violation_type_Housing Complaints':'count_housing_complaints'})

# %%
housing_complaints_counts_df
# Out:
#                       address  count_housing_complaints  kmeans_labels
# 0      1 Abbotsford St, 02121                         0             20
# 1           1 Acorn St, 02108                         1            170
# 2           1 Adams St, 02129                         0             20
# 3           1 Akron Pl, 02119                         0             20
# 4           1 Aldie St, 02134                         0             20
# ...                       ...                       ...            ...
# 25555     994 River St, 02136                         0            126
# 25556    995 Centre St, 02130                         0             20
# 25557     996 South St, 02131                         0             20
# 25558   998 Tremont St, 02120                         1            199
# 25559     999 South St, 02131                         0             20
#
# [25560 rows x 3 columns]

# %%
#Source: https://geospatialawarenesshub.com/blog/simple-tricks-for-geocoding-any-address-plotting-maps-using-python/
geoms = []
found_address = []
for address in lf.address_str.values:
    # print (row['Name'])
    info = geocode((address), provider='arcgis')#(timeout=3))
    #data_cleaned.loc[int(index), 'Address']= info['address'].loc[0]
    # data_cleaned.loc[int(index), 'lon']=info['geometry'].loc[0].x
    # data_cleaned.loc[int(index), 'lat']=info['geometry'].loc[0].y
    geoms.append(info.geometry[0])
    found_address.append(info.address[0])
    # print(info,address)
    # break

# %%
df = geopandas.read_file('address_clusters_withcomp.csv').set_index('address')

# %%
df
# Out:
#                        violation_type_Building Violations  \
# address
# 1 Abbotsford St, 02121                                  0
# 1 Acorn St, 02108                                       0
# 1 Adams St, 02129                                       0
# 1 Akron Pl, 02119                                       0
# 1 Aldie St, 02134                                       0
# ...                                                   ...
# 994 River St, 02136                                     0
# 995 Centre St, 02130                                    0
# 996 South St, 02131                                     0
# 998 Tremont St, 02120                                   0
# 999 South St, 02131                                     0
#
#                        violation_type_Civic Maintenance Requests  \
# address
# 1 Abbotsford St, 02121                                         0
# 1 Acorn St, 02108                                              0
# ...

# %%
db['Pct_Leave_lag'] = weights.spatial_lag.lag_spatial(
    w, db['Pct_Leave']
)
